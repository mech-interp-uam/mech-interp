# %% [markdown]
# # Latentes interpretables obtenidos

# %% [markdown]
# Tras correr el entrenamiento del SAE en 7.7M vectores de activacion, durante 256 epochs en un JumpReLU SAE con parámetros: $d_{\text{model}} = 2048$ y $d_{\text{sae}} = 24 * d_{\text{model}}$, y haber obtenido las localizaciones de los tokens de máxima activacion para cada uno de los latentes y las ventanas de texto alrededor de ellas, algunas de ellas fueron inspeccionadas manualmente, y se encontraron los siguientes latentes (características/[say here if columns or rows of the enc])

# %% [markdown]
# ## Caracterísitca 517: Optimalidad
# ![SAE Dim 10 tokens](latent-517-optimality.png)
